# %%
pip install opencv-python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# !git clone https://github.com/FaridRash/SIFT-Learning SIFT
# Out:
# Cloning into 'SIFT'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 3 (delta 0), reused 3 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (3/3), 2.23 MiB | 6.34 MiB/s, done.

# %%
import cv2
import matplotlib.pyplot as plt

# %%
# Load image in grayscale
image = cv2.imread("/kaggle/working/SIFT/your_image.jpg", cv2.IMREAD_GRAYSCALE)

# Initialize SIFT detector
sift = cv2.SIFT_create()

# %%
# Detect keypoints and descriptors
keypoints, descriptors = sift.detectAndCompute(image, None)

# %%
# Draw keypoints
output = cv2.drawKeypoints(image, keypoints, None, flags=cv2.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS)

# %%
# Display using Matplotlib
plt.figure(figsize=(8, 6))
plt.imshow(output, cmap="gray")
plt.axis("off")
plt.show()
